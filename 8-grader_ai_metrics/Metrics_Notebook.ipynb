# %% [markdown]
# # Metrics Notebook 📊

# %% [markdown]
# ## Imports & Setup

# %%
import pandas as pd
import json
import time
from typing import List, Dict, Any
import pandas as pd
from pathlib import Path
import sys
import openai
from dotenv import load_dotenv
import os
import plotly.graph_objects as go
from plotly.subplots import make_subplots


from llama_index.core import (
    StorageContext,
    load_index_from_storage
)

# %%
#BASE_DIR = Path().resolve().parent
#sys.path.append(str(BASE_DIR / "5-game_physics_awareness"))

#from engine import MagicJudgeEngine

# %% [markdown]
# ## Query Function 🤔

# %%
def ask_judge(
    judge, 
    question: str,
    history: List[Dict] = None,
    collect_tokens: bool = False
) -> Dict[str, Any]:
    """
    Realiza una consulta al juez. 
    Robusta a fallos: Si explota, devuelve un diccionario con el error 
    en lugar de detener todo el script de evaluación.
    """
    if history is None:
        history = []

    t_start = time.time()
    
    # Variables de control
    full_response = ""
    tokens = []
    error_msg = None
    success = False

    try:
        # Ejecutamos la query
        stream = judge.query(question, history=history)

        # Consumimos el stream
        for token in stream:
            # Manejo defensivo por si LlamaIndex cambia la estructura del objeto
            delta = getattr(token, "delta", str(token))
            
            if delta:
                full_response += delta
                if collect_tokens:
                    tokens.append(delta)
        
        success = True

    except Exception as e:
        # Capturamos el error para que el loop de 100 preguntas no se detenga
        error_msg = str(e)
        print(f"⚠️ Error procesando pregunta: {question[:30]}... | {error_msg}")

    latency = time.time() - t_start

    return {
        "question": question,
        "generated_answer": full_response.strip(), # Limpiamos espacios
        "ground_truth": None, # Esto lo llenarás tú después al cruzar con tu dataset
        "latency": latency,
        "success": success,
        "error": error_msg,
        "tokens": tokens if collect_tokens else None
    }

# %%
judge = MagicJudgeEngine()
# Out:
# [LOG] Loading Rules Index...
# [LOG] Loading Cards Index...

# %%
# prueba con una pregunta
question = "If I attack with a creature with Deathtouch and Trample and it gets blocked, how much damage do I need to assign to the blocker?"
response = ask_judge(judge,question)
# Out:
# [LOG] Search Query: If I attack with a creature with Deathtouch and Trample and it gets blocked, how much damage do I need to assign to the blocker?
# [LOG] No exact cards found. Running semantic search.
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Rule] 702.19b                        (sc: 0.70)
#  - [Rule] 702.19d                        (sc: 0.64)
#  - [Rule] 510.1c                         (sc: 0.63)
#  - [Rule] 702.19e                        (sc: 0.61)
#  - [Rule] 510.1d                         (sc: 0.60)
#  - [Rule] 702.2c                         (sc: 0.59)
#  - [Card] Enlarge                        (sc: 0.59)
#  - [Rule] 510.1a                         (sc: 0.58)
#  - [Rule] 510.1                          (sc: 0.58)
#  - [Card] Ride Down                      (sc: 0.57)
#  - [Card] Mirror Shield                  (sc: 0.55)
#  - [Card] Deathcoil Wurm                 (sc: 0.54)
#  - [Card] Fight to the Death             (sc: 0.54)
# ============================================================

# %%
response
# Out:
# {'question': 'If I attack with a creature with Deathtouch and Trample and it gets blocked, how much damage do I need to assign to the blocker?',
#  'generated_answer': 'Ah, the intricacies of combat damage assignment! Let us delve into the mechanics of trample and deathtouch, which can often lead to confusion.\n\n### 1. The Interaction\nYou are attacking with a creature that possesses both deathtouch and trample, and it has been blocked by an opposing creature. \n\n### 2. The Logic (Step-by-Step)\n- **Deathtouch**: This ability stipulates that any amount of damage dealt to a creature is considered lethal damage. Thus, even a single point of damage from your creature is sufficient to satisfy the requirement for lethal damage.\n- **Trample**: When a creature with trample is blocked, the controller must assign enough damage to the blocking creature to meet the lethal damage requirement before assigning any excess damage to the defending player or planeswalker. \n\nNow, since your creature has deathtouch, you need only assign **1 damage** to the blocking creature to satisfy the lethal damage requirement. After that, any remaining damage can be assigned to the defending player or planeswalker.\n\nCrucially, if your creature has, for example, a power of 5, you would assign 1 damage to the blocker (due to deathtouch) and the remaining 4 damage can be assigned to the defending player or planeswalker.\n\n### 3. The Ruling\nYou must assign at least 1 damage to the blocking creature, and any excess damage can be assigned to the defending player or planeswalker.\n\n### Sources\n[[Deathtouch]], [Rule 702.2c]  \n[[Trample]], [Rule 702.19b]  \n[[Combat Damage Assignment]], [Rule 510.1]',
#  'ground_truth': None,
#  'latency': 13.293503999710083,
#  'success': True,
#  'error': None,
#  'tokens': None}

# %% [markdown]
# ## Dataset Questions and answers ⁉️

# %%
BASE_DIR = Path().resolve().parent
sys.path.append(str(BASE_DIR / "7-grader_ai_metrics"))

# 1. Cargar el archivo JSON
with open('curated_questions.json', 'r', encoding='utf-8') as f:
    data = json.load(f)

# 2. Crear el DataFrame de Definiciones (Metadata)
#df_bloques = pd.DataFrame(data['blocks_definition'])

# 3. Crear el DataFrame de Preguntas
df_questions = pd.DataFrame(data)

# %%
df_questions.head(20)
# Out:
#     id                                           question  \
# 0    1  I control [[Vizier of Remedies]] and [[Devoted...
# 1    2  I attack with [[Questing Beast]] and my oppone...
# 2    3  If my opponent casts [[Solitude]] on my [[Ketr...
# 3    4  I cast [[Dress Down]] and my opponent has a [[...
# 4    5  If I cast [[Merfolk Trickster]] on [[Dryad of ...
# 5    6  If I have an [[Urza's Saga]] on chapter II and...
# 6    7  I cast a [[Dragonhawk, Fate's Tempest]] exilin...
# 7    8  If my opponent controls [[The One Ring]] with ...
# 8    9  If I cast [[Phantasmal Image]] on an activated...
# 9   10  Can I pay life to [[Bolas's Citadel]] and go t...
# 10  11  Do I draw from [[Dark Confidant]] if my life w...
# 11  12  If I discarded a nonland card to [[Grab the Pr...
# 12  13  If I have an active [[Purphoros, God of the Fo...
# 13  14  I have a [[Utopia Sprawl]] enchanting a [[Bree...
# 14  15  If I have a [[Chalice of the Void]] with 0 cou...
# 15  16  I cast [[Taunting Elf]] and have a [[Jaspera S...
# 16  17  If I cast [[Seasoned Pyromancer]] with an exer...
# 17  18  If I cast [[Treachery]] on an opponent's [[Eid...
# 18  19  If I cast [[Ephemerate]] on my [[Master of Wav...
# 19  20  If I cast [[Clone]] on a creature enchanted wi...
#
#                                       accepted_answer difficulty  \
# 0   Yes, you can. This works because the Vizier cr...       hard
# 1   Yes, with Questing Beast attacking, casting Fo...       hard
# 2   Yes, you will draw a card. Ketramose's ability...       hard
# 3   Yes, your non-basic lands will still be mounta...       hard
# 4   Yes, the lands remain Mountains. This happens ...       hard
# 5   When your opponent plays Blood Moon while your...       hard
# 6   Yes, the Dragonhawk's end-step ability will st...       hard
# 7   Your opponent draws 2 cards. This happens beca...       hard
# 8   No, when Phantasmal Image copies an activated ...       hard
# 9   No, you cannot pay life to Bolas's Citadel and...       hard
# 10  Yes, you still draw from Dark Confidant even i...       hard
# 11  Yes, the copied Grab the Prize will deal 2 dam...       hard
# 12  Purphoros remains a Toy creature, and the Aura...       hard
# 13  When you play Harbinger of the Seas, it turns ...       hard
# 14  No, the Walking Ballista will not be countered...       hard
# 15  Yes, you can use the Jaspera Sentinel to tap t...       hard
# 16  No, the tokens do not have haste. Arena of Glo...       hard
# 17  Yes. You control the Eidolon as soon as Treach...       hard
# 18  No, the tokens do not die. This happens becaus...       hard
# 19  If you cast Clone on a creature enchanted with...       hard
#
#                                 category
# 0     Costs, Mana & Casting Requirements
# 1              Combat & Damage Mechanics
# 2   Zones, Objects & State-Based Actions
# 3   Continuous Effects, Layers & Copying
# 4   Continuous Effects, Layers & Copying
# 5   Continuous Effects, Layers & Copying
# 6           The Stack, Timing & Priority
# 7           The Stack, Timing & Priority
# 8   Continuous Effects, Layers & Copying
# 9     Costs, Mana & Casting Requirements
# 10  Zones, Objects & State-Based Actions
# 11    Costs, Mana & Casting Requirements
# 12  Continuous Effects, Layers & Copying
# 13  Continuous Effects, Layers & Copying
# 14          The Stack, Timing & Priority
# 15    Costs, Mana & Casting Requirements
# 16    Costs, Mana & Casting Requirements
# 17  Zones, Objects & State-Based Actions
# 18  Zones, Objects & State-Based Actions
# 19  Continuous Effects, Layers & Copying

# %%
# generar respuestas con clase

def get_responses(row):
    question = row['question']
    response = ask_judge(judge, question)
    return response['generated_answer']

df_questions['model_answer'] = df_questions.apply(get_responses, axis=1)
# Out:
# [LOG] Search Query: I control [[Vizier of Remedies]] and [[Devoted Druid]]. Can I generate infinite Green mana?
# [LOG] Target Cards Identified: ['Vizier of Remedies', 'Devoted Druid']
#    >>> Found Card: Vizier of Remedies
#    >>> Found Card: Devoted Druid
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Vizier of Remedies             (sc: 2.00)
#  - [Card] Devoted Druid                  (sc: 2.00)
#  - [Rule] 106.7                          (sc: 0.52)
#  - [Rule] 106.6                          (sc: 0.49)
#  - [Rule] 605.2                          (sc: 0.49)
#  - [Rule] 701.44a                        (sc: 0.48)
#  - [Rule] 700.5a                         (sc: 0.48)
#  - [Rule] 305.2                          (sc: 0.47)
#  - [Rule] 700.14                         (sc: 0.47)
#  - [Rule] 605.3c                         (sc: 0.47)
# ============================================================
#
# [LOG] Search Query: I attack with [[Questing Beast]] and my opponent casts [[Fog]]. Does damage go through?
# [LOG] Target Cards Identified: ['Fog', 'Questing Beast']
#    >>> Found Card: Fog
#    >>> Found Card: Questing Beast
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Fog                            (sc: 2.00)
#  - [Card] Questing Beast                 (sc: 2.00)
#  - [Rule] 702.20b                        (sc: 0.48)
#  - [Rule] 506.3b                         (sc: 0.47)
#  - [Rule] 702.22j                        (sc: 0.46)
#  - [Rule] 701.43d                        (sc: 0.46)
#  - [Rule] 506.3c                         (sc: 0.46)
#  - [Rule] 510.1                          (sc: 0.46)
#  - [Rule] 120.4d                         (sc: 0.46)
#  - [Rule] 508.4b                         (sc: 0.45)
# ============================================================
#
# [LOG] Search Query: If my opponent casts [[Solitude]] on my [[Ketramose]] during my turn, do I draw a card from [[Ketramose]]'s ability?
# [LOG] Target Cards Identified: ['Ketramose', 'Solitude']
#    >>> Found Card: Solitude
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Solitude                       (sc: 2.00)
#  - [Rule] 121.3                          (sc: 0.42)
#  - [Rule] 712.13a                        (sc: 0.42)
#  - [Rule] 704.4                          (sc: 0.41)
#  - [Rule] 121.8                          (sc: 0.41)
#  - [Rule] 614.13c                        (sc: 0.40)
#  - [Rule] 118.12                         (sc: 0.40)
#  - [Rule] 400.7k                         (sc: 0.40)
#  - [Rule] 607.3                          (sc: 0.40)
# ============================================================
#
# [LOG] Search Query: I cast [[Dress Down]] and my opponent has a [[Magus of the Moon]] in play. Are my non-basic lands still mountains?
# [LOG] Target Cards Identified: ['Dress Down', 'Magus of the Moon']
#    >>> Found Card: Dress Down
#    >>> Found Card: Magus of the Moon
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Dress Down                     (sc: 2.00)
#  - [Card] Magus of the Moon              (sc: 2.00)
#  - [Rule] 305.6                          (sc: 0.54)
#  - [Rule] 205.4c                         (sc: 0.53)
#  - [Rule] 505.6b                         (sc: 0.51)
#  - [Rule] Basic Land Type                (sc: 0.50)
#  - [Rule] 305.8                          (sc: 0.49)
#  - [Rule] 305.1                          (sc: 0.49)
#  - [Rule] 903.12e                        (sc: 0.49)
#  - [Rule] Mountain                       (sc: 0.49)
# ============================================================
#
# [LOG] Search Query: If I cast [[Merfolk Trickster]] on [[Dryad of the Ilysian Grove]], will my opponent's [[Valakut]] see his lands as mountains?
# [LOG] Target Cards Identified: ['Valakut', 'Merfolk Trickster', 'Dryad of the Ilysian Grove']
#    >>> Found Card: Merfolk Trickster
#    >>> Found Card: Dryad of the Ilysian Grove
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Merfolk Trickster              (sc: 2.00)
#  - [Card] Dryad of the Ilysian Grove     (sc: 2.00)
#  - [Rule] Plainswalk                     (sc: 0.47)
#  - [Rule] 701.44a                        (sc: 0.47)
#  - [Rule] 305.4                          (sc: 0.46)
#  - [Rule] 712.13a                        (sc: 0.46)
#  - [Rule] 400.7i                         (sc: 0.46)
#  - [Rule] 613.6                          (sc: 0.45)
#  - [Rule] 305.2a                         (sc: 0.45)
#  - [Rule] Swampwalk                      (sc: 0.45)
# ============================================================
#
# [LOG] Search Query: If I have an [[Urza's Saga]] on chapter II and my opponent plays a [[Blood Moon]], what happens to my [[Urza's Saga]]?
# [LOG] Target Cards Identified: ['Blood Moon', "Urza's Saga"]
#    >>> Found Card: Blood Moon
#    >>> Found Card: Urza's Saga
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Blood Moon                     (sc: 2.00)
#  - [Card] Urza's Saga                    (sc: 2.00)
#  - [Rule] 505.4                          (sc: 0.53)
#  - [Rule] 712.21d                        (sc: 0.51)
#  - [Rule] 702.155b                       (sc: 0.51)
#  - [Rule] 704.5s                         (sc: 0.50)
#  - [Rule] 714.3b                         (sc: 0.49)
#  - [Rule] 714.4                          (sc: 0.49)
#  - [Rule] 703.4f                         (sc: 0.49)
#  - [Rule] 712.13a                        (sc: 0.48)
# ============================================================
#
# [LOG] Search Query: I cast a [[Dragonhawk, Fate's Tempest]] exiling 2 cards, but my opponent kills it right away with [[Shoot the Sheriff]]. On my end step, I still have the 2 cards in exile. Does the [[Dragonhawk]] still do damage to my opponent even if it is in the graveyard?
# [LOG] Target Cards Identified: ["Dragonhawk, Fate's Tempest", 'Shoot the Sheriff', 'Dragonhawk']
#    >>> Found Card: Dragonhawk, Fate's Tempest
#    >>> Found Card: Shoot the Sheriff
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Dragonhawk, Fate's Tempest     (sc: 2.00)
#  - [Card] Shoot the Sheriff              (sc: 2.00)
#  - [Rule] 715.3d                         (sc: 0.52)
#  - [Rule] 712.21c                        (sc: 0.51)
#  - [Rule] 400.7k                         (sc: 0.51)
#  - [Rule] 616.1f                         (sc: 0.49)
#  - [Rule] 120.5                          (sc: 0.49)
#  - [Rule] 701.24c                        (sc: 0.48)
#  - [Rule] 702.35c                        (sc: 0.48)
#  - [Rule] 702.85b                        (sc: 0.47)
# ============================================================
#
# [LOG] Search Query: If my opponent controls [[The One Ring]] with 2 counters and activates it, and I exile it in response with [[Tear Asunder]], does my opponent draw 2 cards, 3 cards, or 0 cards?
# [LOG] Target Cards Identified: ['Tear Asunder', 'The One Ring']
#    >>> Found Card: Tear Asunder
#    >>> Found Card: The One Ring
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Tear Asunder                   (sc: 2.00)
#  - [Card] The One Ring                   (sc: 2.00)
#  - [Rule] 607.3                          (sc: 0.50)
#  - [Rule] 614.11b                        (sc: 0.49)
#  - [Rule] 704.7                          (sc: 0.49)
#  - [Rule] 406.4                          (sc: 0.48)
#  - [Rule] 616.1f                         (sc: 0.48)
#  - [Rule] 104.3c                         (sc: 0.47)
#  - [Rule] 121.2                          (sc: 0.47)
#  - [Rule] 121.2b                         (sc: 0.47)
# ============================================================
#
# [LOG] Search Query: If I cast [[Phantasmal Image]] on an activated [[Mutavault]], do I get a 2/2 creature that does not need activation?
# [LOG] Target Cards Identified: ['Phantasmal Image', 'Mutavault']
#    >>> Found Card: Phantasmal Image
#    >>> Found Card: Mutavault
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Phantasmal Image               (sc: 2.00)
#  - [Card] Mutavault                      (sc: 2.00)
#  - [Rule] 712.13a                        (sc: 0.50)
#  - [Rule] 602.5a                         (sc: 0.48)
#  - [Rule] 118.12                         (sc: 0.48)
#  - [Rule] 702.140c                       (sc: 0.47)
#  - [Rule] 110.5b                         (sc: 0.47)
#  - [Rule] 302.6                          (sc: 0.47)
#  - [Rule] 712.9                          (sc: 0.47)
#  - [Rule] 506.3c                         (sc: 0.47)
# ============================================================
#
# [LOG] Search Query: Can I pay life to [[Bolas's Citadel]] and go to negative life if I have a [[Platinum Angel]]?
# [LOG] Target Cards Identified: ['Platinum Angel', "Bolas's Citadel"]
#    >>> Found Card: Platinum Angel
#    >>> Found Card: Bolas's Citadel
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Platinum Angel                 (sc: 2.00)
#  - [Card] Bolas's Citadel                (sc: 2.00)
#  - [Rule] 119.4b                         (sc: 0.53)
#  - [Rule] 119.4                          (sc: 0.53)
#  - [Rule] 118.3b                         (sc: 0.52)
#  - [Rule] 810.9b                         (sc: 0.51)
#  - [Rule] 119.4a                         (sc: 0.48)
#  - [Rule] 119.8                          (sc: 0.47)
#  - [Rule] 119.7                          (sc: 0.46)
#  - [Rule] 810.9a                         (sc: 0.46)
# ============================================================
#
# [LOG] Search Query: Do I draw from [[Dark Confidant]] if my life would go to negative but I have a [[Platinum Angel]] out?
# [LOG] Target Cards Identified: ['Platinum Angel', 'Dark Confidant']
#    >>> Found Card: Platinum Angel
#    >>> Found Card: Dark Confidant
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Platinum Angel                 (sc: 2.00)
#  - [Card] Dark Confidant                 (sc: 2.00)
#  - [Rule] 704.7                          (sc: 0.42)
#  - [Rule] 702.15e                        (sc: 0.41)
#  - [Rule] 107.1b                         (sc: 0.41)
#  - [Rule] 119.10                         (sc: 0.40)
#  - [Rule] 701.12c                        (sc: 0.40)
#  - [Rule] 810.9a                         (sc: 0.40)
#  - [Rule] 119.8                          (sc: 0.40)
#  - [Rule] 400.6                          (sc: 0.39)
# ============================================================
#
# [LOG] Search Query: If I discarded a nonland card to [[Grab the Prize]] and managed to copy the spell, does the copy also deal the 2 damage?
# [LOG] Target Cards Identified: ['Grab the Prize']
#    >>> Found Card: Grab the Prize
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Grab the Prize                 (sc: 2.00)
#  - [Rule] 112.1b                         (sc: 0.57)
#  - [Rule] 707.10                         (sc: 0.56)
#  - [Rule] 112.1a                         (sc: 0.54)
#  - [Rule] 707.10c                        (sc: 0.54)
#  - [Rule] 707.10g                        (sc: 0.52)
#  - [Rule] Demonstrate                    (sc: 0.52)
#  - [Rule] 707.10e                        (sc: 0.52)
#  - [Rule] 616.1c                         (sc: 0.52)
# ============================================================
#
# [LOG] Search Query: If I have an active [[Purphoros, God of the Forge]] enchanted by [[Unable to Scream]], what happens if my devotion drops below 5? Does the aura fall? Is [[Purphoros]] still a Toy creature?
# [LOG] Target Cards Identified: ['Unable to Scream', 'Purphoros, God of the Forge', 'Purphoros']
#    >>> Found Card: Unable to Scream
#    >>> Found Card: Purphoros, God of the Forge
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Unable to Scream               (sc: 2.00)
#  - [Card] Purphoros, God of the Forge    (sc: 2.00)
#  - [Rule] 700.5a                         (sc: 0.58)
#  - [Rule] 303.4c                         (sc: 0.49)
#  - [Rule] 303.4d                         (sc: 0.49)
#  - [Rule] 702.16p                        (sc: 0.48)
#  - [Rule] 303.4i                         (sc: 0.48)
#  - [Rule] 400.7f                         (sc: 0.47)
#  - [Rule] 303.4g                         (sc: 0.47)
#  - [Rule] 303.4j                         (sc: 0.47)
# ============================================================
#
# [LOG] Search Query: I have a [[Utopia Sprawl]] enchanting a [[Breeding Pool]], and play a [[Harbinger of the Seas]]; does the [[Utopia Sprawl]] stay on the land, or fall off?
# [LOG] Target Cards Identified: ['Breeding Pool', 'Harbinger of the Seas', 'Utopia Sprawl']
#    >>> Found Card: Breeding Pool
#    >>> Found Card: Harbinger of the Seas
#    >>> Found Card: Utopia Sprawl
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Breeding Pool                  (sc: 2.00)
#  - [Card] Harbinger of the Seas          (sc: 2.00)
#  - [Card] Utopia Sprawl                  (sc: 2.00)
#  - [Rule] 701.44a                        (sc: 0.47)
#  - [Rule] 614.13c                        (sc: 0.46)
#  - [Rule] 303.2                          (sc: 0.45)
#  - [Rule] 603.6b                         (sc: 0.45)
#  - [Rule] 712.21d                        (sc: 0.45)
#  - [Rule] Swampwalk                      (sc: 0.45)
#  - [Rule] 616.1f                         (sc: 0.44)
#  - [Rule] 611.3d                         (sc: 0.44)
# ============================================================
#
# [LOG] Search Query: If I have a [[Chalice of the Void]] with 0 counters and my opponent plays a [[Walking Ballista]] paying 4 mana? Does the [[Ballista]] get countered? What is its CMC on the stack?
# [LOG] Target Cards Identified: ['Chalice of the Void', 'Ballista', 'Walking Ballista']
#    >>> Found Card: Chalice of the Void
#    >>> Found Card: Walking Ballista
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Chalice of the Void            (sc: 2.00)
#  - [Card] Walking Ballista               (sc: 2.00)
#  - [Rule] 701.6b                         (sc: 0.46)
#  - [Rule] 122.6                          (sc: 0.45)
#  - [Rule] 122.6a                         (sc: 0.45)
#  - [Rule] 113.9                          (sc: 0.45)
#  - [Rule] 107.3h                         (sc: 0.45)
#  - [Rule] 107.3g                         (sc: 0.44)
#  - [Rule] 509.1d                         (sc: 0.44)
#  - [Rule] 605.3b                         (sc: 0.44)
# ============================================================
#
# [LOG] Search Query: I cast [[Taunting Elf]] and have a [[Jaspera Sentinel]] in play. Can I use the Sentinel to tap the Elf for mana right away? Or the Elf's summoning sickness prevents me from that?
# [LOG] Target Cards Identified: ['Jaspera Sentinel', 'Taunting Elf']
#    >>> Found Card: Jaspera Sentinel
#    >>> Found Card: Taunting Elf
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Jaspera Sentinel               (sc: 2.00)
#  - [Card] Taunting Elf                   (sc: 2.00)
#  - [Rule] Summoning Sickness Rule        (sc: 0.53)
#  - [Rule] 302.6                          (sc: 0.47)
#  - [Rule] 616.1f                         (sc: 0.44)
#  - [Rule] 118.12                         (sc: 0.44)
#  - [Rule] 702.154a                       (sc: 0.43)
#  - [Rule] 702.10c                        (sc: 0.43)
#  - [Rule] 702.180b                       (sc: 0.43)
#  - [Rule] 702.62c                        (sc: 0.43)
# ============================================================
#
# [LOG] Search Query: If I cast [[Seasoned Pyromancer]] with an exerted [[Arena of Glory]], creating 2 elemental tokens, do the tokens have haste too?
# [LOG] Target Cards Identified: ['Arena of Glory', 'Seasoned Pyromancer']
#    >>> Found Card: Arena of Glory
#    >>> Found Card: Seasoned Pyromancer
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Arena of Glory                 (sc: 2.00)
#  - [Card] Seasoned Pyromancer            (sc: 2.00)
#  - [Rule] 702.10                         (sc: 0.51)
#  - [Rule] 702.10a                        (sc: 0.49)
#  - [Rule] 702.10c                        (sc: 0.49)
#  - [Rule] 616.1g                         (sc: 0.48)
#  - [Rule] 702.10b                        (sc: 0.47)
#  - [Rule] 702.10d                        (sc: 0.46)
#  - [Rule] 702.103d                       (sc: 0.45)
#  - [Rule] 601.3b                         (sc: 0.45)
# ============================================================
#
# [LOG] Search Query: If I cast [[Treachery]] on an opponent's [[Eidolon of Blossoms]], do I draw a card? If so, what is the rule?
# [LOG] Target Cards Identified: ['Eidolon of Blossoms', 'Treachery']
#    >>> Found Card: Eidolon of Blossoms
#    >>> Found Card: Treachery
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Eidolon of Blossoms            (sc: 2.00)
#  - [Card] Treachery                      (sc: 2.00)
#  - [Rule] 118.12                         (sc: 0.52)
#  - [Rule] 614.11b                        (sc: 0.50)
#  - [Rule] 616.1f                         (sc: 0.50)
#  - [Rule] 601.3f                         (sc: 0.50)
#  - [Rule] 702.74a                        (sc: 0.49)
#  - [Rule] 703.4d                         (sc: 0.49)
#  - [Rule] 406.3b                         (sc: 0.48)
#  - [Rule] 121.3                          (sc: 0.48)
# ============================================================
#
# [LOG] Search Query: If I cast [[Ephemerate]] on my [[Master of Waves]] with 4 Elemental tokens out, do the tokens die?
# [LOG] Target Cards Identified: ['Ephemerate', 'Master of Waves']
#    >>> Found Card: Ephemerate
#    >>> Found Card: Master of Waves
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Ephemerate                     (sc: 2.00)
#  - [Card] Master of Waves                (sc: 2.00)
#  - [Rule] 712.21                         (sc: 0.46)
#  - [Rule] 712.21c                        (sc: 0.46)
#  - [Rule] 616.1f                         (sc: 0.44)
#  - [Rule] 712.21d                        (sc: 0.44)
#  - [Rule] 729.3e                         (sc: 0.43)
#  - [Rule] 702.128b                       (sc: 0.43)
#  - [Rule] 701.42c                        (sc: 0.42)
#  - [Rule] 608.3f                         (sc: 0.42)
# ============================================================
#
# [LOG] Search Query: If I cast [[Clone]] on a creature enchanted with [[Lignify]], will it copy the original creature or a 0/4 Treefolk?
# [LOG] Target Cards Identified: ['Clone', 'Lignify']
#    >>> Found Card: Clone
#    >>> Found Card: Lignify
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Clone                          (sc: 2.00)
#  - [Card] Lignify                        (sc: 2.00)
#  - [Rule] 707.2                          (sc: 0.59)
#  - [Rule] 707.9a                         (sc: 0.57)
#  - [Rule] 707.3                          (sc: 0.56)
#  - [Rule] 707.5                          (sc: 0.54)
#  - [Rule] 707.6                          (sc: 0.54)
#  - [Rule] 608.3e                         (sc: 0.54)
#  - [Rule] 707.9e                         (sc: 0.53)
#  - [Rule] 707.4                          (sc: 0.51)
# ============================================================
#
# [LOG] Search Query: If [[Phantasmal Image]] is copying a black creature, can I kill it with [[Terror]]?
# [LOG] Target Cards Identified: ['Phantasmal Image', 'Terror']
#    >>> Found Card: Phantasmal Image
#    >>> Found Card: Terror
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Phantasmal Image               (sc: 2.00)
#  - [Card] Terror                         (sc: 2.00)
#  - [Rule] 702.36b                        (sc: 0.50)
#  - [Rule] 707.3                          (sc: 0.47)
#  - [Rule] 707.9d                         (sc: 0.47)
#  - [Rule] 712.13a                        (sc: 0.46)
#  - [Rule] 616.1c                         (sc: 0.44)
#  - [Rule] 707.9f                         (sc: 0.44)
#  - [Rule] 707.10e                        (sc: 0.44)
#  - [Rule] 608.2b                         (sc: 0.44)
# ============================================================
#
# [LOG] Search Query: Can I destroy a [[Phantasmal Bear]] using [[Hydroblast]], since I can target it?
# [LOG] Target Cards Identified: ['Phantasmal Bear', 'Hydroblast']
#    >>> Found Card: Phantasmal Bear
#    >>> Found Card: Hydroblast
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Phantasmal Bear                (sc: 2.00)
#  - [Card] Hydroblast                     (sc: 2.00)
#  - [Rule] 115.2                          (sc: 0.46)
#  - [Rule] 120.5                          (sc: 0.46)
#  - [Rule] 614.13b                        (sc: 0.42)
#  - [Rule] 701.8b                         (sc: 0.41)
#  - [Rule] 608.2b                         (sc: 0.41)
#  - [Rule] 801.7a                         (sc: 0.40)
#  - [Rule] 115.4                          (sc: 0.40)
#  - [Rule] 701.8a                         (sc: 0.39)
# ============================================================
#
# [LOG] Search Query: Does [[Wasteland Strangler]] need a card in exile for its ability to work? If I cast [[Strangler]] on my opponent's [[Phantasmal Bear]] while he does not have cards in exile? Can I target the bear so it dies?
# [LOG] Target Cards Identified: ['Phantasmal Bear', 'Strangler', 'Wasteland Strangler']
#    >>> Found Card: Phantasmal Bear
#    >>> Found Card: Wasteland Strangler
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Phantasmal Bear                (sc: 2.00)
#  - [Card] Wasteland Strangler            (sc: 2.00)
#  - [Rule] 614.13a                        (sc: 0.51)
#  - [Rule] 712.21c                        (sc: 0.51)
#  - [Rule] 801.7a                         (sc: 0.50)
#  - [Rule] 702.55b                        (sc: 0.50)
#  - [Rule] 701.23b                        (sc: 0.50)
#  - [Rule] 712.21d                        (sc: 0.49)
#  - [Rule] 712.21b                        (sc: 0.49)
#  - [Rule] 702.185b                       (sc: 0.49)
# ============================================================
#
# [LOG] Search Query: I cast [[Tidehollow Sculler]]. In response to its 'enter the battlefield' ability, I cast [[Cloudshift]] on it. What happens?
# [LOG] Target Cards Identified: ['Cloudshift', 'Tidehollow Sculler']
#    >>> Found Card: Cloudshift
#    >>> Found Card: Tidehollow Sculler
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Cloudshift                     (sc: 2.00)
#  - [Card] Tidehollow Sculler             (sc: 2.00)
#  - [Rule] 712.13a                        (sc: 0.50)
#  - [Rule] 616.1f                         (sc: 0.49)
#  - [Rule] 614.13c                        (sc: 0.48)
#  - [Rule] 712.21d                        (sc: 0.48)
#  - [Rule] 702.37c                        (sc: 0.48)
#  - [Rule] 707.5                          (sc: 0.47)
#  - [Rule] 614.12                         (sc: 0.47)
#  - [Rule] 118.12                         (sc: 0.47)
# ============================================================
#
# [LOG] Search Query: Can I activate my [[Spellskite]] in response to my opponent trying to equip his creature with [[Shadowspear]]? Will the [[Shadowspear]] equip [[Spellskite]] instead?
# [LOG] Target Cards Identified: ['Spellskite', 'Shadowspear']
#    >>> Found Card: Spellskite
#    >>> Found Card: Shadowspear
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Spellskite                     (sc: 2.00)
#  - [Card] Shadowspear                    (sc: 2.00)
#  - [Rule] 301.5b                         (sc: 0.54)
#  - [Rule] 118.12                         (sc: 0.50)
#  - [Rule] 712.13a                        (sc: 0.47)
#  - [Rule] 702.6a                         (sc: 0.47)
#  - [Rule] 301.5c                         (sc: 0.47)
#  - [Rule] 702.6d                         (sc: 0.47)
#  - [Rule] 702.6e                         (sc: 0.46)
#  - [Rule] Respond                        (sc: 0.46)
# ============================================================
#
# [LOG] Search Query: If my opponent cast a [[Fatal Push]] on my creature, can I use [[Aether Vial]] in response to put [[Unsettled Mariner]] into play and force him to pay 1 more mana?
# [LOG] Target Cards Identified: ['Aether Vial', 'Fatal Push', 'Unsettled Mariner']
#    >>> Found Card: Aether Vial
#    >>> Found Card: Fatal Push
#    >>> Found Card: Unsettled Mariner
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Aether Vial                    (sc: 2.00)
#  - [Card] Fatal Push                     (sc: 2.00)
#  - [Card] Unsettled Mariner              (sc: 2.00)
#  - [Rule] 118.12                         (sc: 0.47)
#  - [Rule] 605.4a                         (sc: 0.45)
#  - [Rule] 614.13c                        (sc: 0.45)
#  - [Rule] 712.21d                        (sc: 0.45)
#  - [Rule] 616.1f                         (sc: 0.44)
#  - [Rule] 601.3a                         (sc: 0.44)
#  - [Rule] 704.4                          (sc: 0.44)
#  - [Rule] 605.3a                         (sc: 0.44)
# ============================================================
#
# [LOG] Search Query: I cast [[Supernatural Stamina]] on [[Elenda, the Dusk Rose]] in response to a board wipe. When she dies and returns, does she get counters from the other creatures dying? Does the token generation count the +2/+0 buff?
# [LOG] Target Cards Identified: ['Supernatural Stamina', 'Elenda, the Dusk Rose']
#    >>> Found Card: Supernatural Stamina
#    >>> Found Card: Elenda, the Dusk Rose
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Supernatural Stamina           (sc: 2.00)
#  - [Card] Elenda, the Dusk Rose          (sc: 2.00)
#  - [Rule] 704.8                          (sc: 0.52)
#  - [Rule] 702.93a                        (sc: 0.49)
#  - [Rule] 616.1f                         (sc: 0.49)
#  - [Rule] 701.63a                        (sc: 0.48)
#  - [Rule] 120.3d                         (sc: 0.47)
#  - [Rule] 614.16                         (sc: 0.47)
#  - [Rule] Endure                         (sc: 0.47)
#  - [Rule] 712.21c                        (sc: 0.46)
# ============================================================
#
# [LOG] Search Query: Can I use the processor ability of [[Oracle of Dust]] when there is a [[Rest in Peace]] in play?
# [LOG] Target Cards Identified: ['Rest in Peace', 'Oracle of Dust']
#    >>> Found Card: Rest in Peace
#    >>> Found Card: Oracle of Dust
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Rest in Peace                  (sc: 2.00)
#  - [Card] Oracle of Dust                 (sc: 2.00)
#  - [Rule] 108.1                          (sc: 0.50)
#  - [Rule] 702.128a                       (sc: 0.46)
#  - [Rule] 616.1f                         (sc: 0.45)
#  - [Rule] 201.4a                         (sc: 0.45)
#  - [Rule] 304.2                          (sc: 0.45)
#  - [Rule] 702.187a                       (sc: 0.45)
#  - [Rule] 603.10a                        (sc: 0.45)
#  - [Rule] 901.9c                         (sc: 0.44)
# ============================================================
#
# [LOG] Search Query: If I use [[Snapcaster Mage]] to flashback [[Approach of the Second Sun]], where would it go when it resolves?
# [LOG] Target Cards Identified: ['Approach of the Second Sun', 'Snapcaster Mage']
#    >>> Found Card: Approach of the Second Sun
#    >>> Found Card: Snapcaster Mage
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Approach of the Second Sun     (sc: 2.00)
#  - [Card] Snapcaster Mage                (sc: 2.00)
#  - [Rule] 702.34a                        (sc: 0.48)
#  - [Rule] 712.13a                        (sc: 0.48)
#  - [Rule] 712.13                         (sc: 0.46)
#  - [Rule] 400.7k                         (sc: 0.45)
#  - [Rule] 702.35c                        (sc: 0.45)
#  - [Rule] 712.21c                        (sc: 0.45)
#  - [Rule] 307.2                          (sc: 0.44)
#  - [Rule] 608.2m                         (sc: 0.44)
# ============================================================
#
# [LOG] Search Query: If a [[Field-Tested Frying Pan]] enters the battlefield while I control [[Peregrin Took]], how many food tokens would I create in total?
# [LOG] Target Cards Identified: ['Field-Tested Frying Pan', 'Peregrin Took']
#    >>> Found Card: Field-Tested Frying Pan
#    >>> Found Card: Peregrin Took
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Field-Tested Frying Pan        (sc: 2.00)
#  - [Card] Peregrin Took                  (sc: 2.00)
#  - [Rule] Food Token                     (sc: 0.43)
#  - [Rule] 111.10b                        (sc: 0.43)
#  - [Rule] 702.174d                       (sc: 0.42)
#  - [Rule] 616.1g                         (sc: 0.38)
#  - [Rule] 701.7a                         (sc: 0.37)
#  - [Rule] 701.61a                        (sc: 0.37)
#  - [Rule] 701.53a                        (sc: 0.35)
#  - [Rule] 614.13b                        (sc: 0.35)
# ============================================================
#
# [LOG] Search Query: If I manifest [[Nexus of Fate]] with [[Abhorrent Oculus]] and the manifested creature dies, will [[Nexus of Fate]]'s replacement trigger activate and put it back in library or does it simply hit the graveyard stay there?
# [LOG] Target Cards Identified: ['Nexus of Fate', 'Abhorrent Oculus']
#    >>> Found Card: Nexus of Fate
#    >>> Found Card: Abhorrent Oculus
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Nexus of Fate                  (sc: 2.00)
#  - [Card] Abhorrent Oculus               (sc: 2.00)
#  - [Rule] 712.21c                        (sc: 0.54)
#  - [Rule] 712.21d                        (sc: 0.52)
#  - [Rule] 603.10a                        (sc: 0.52)
#  - [Rule] 616.1f                         (sc: 0.52)
#  - [Rule] 701.24c                        (sc: 0.52)
#  - [Rule] 701.24g                        (sc: 0.51)
#  - [Rule] 720.3d                         (sc: 0.51)
#  - [Rule] 712.21                         (sc: 0.51)
# ============================================================
#
# [LOG] Search Query: If I turn a manifested creature face-up in response to [[Path to Exile]], does the spell fizzle?
# [LOG] Target Cards Identified: ['Path to Exile']
#    >>> Found Card: Path to Exile
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Path to Exile                  (sc: 2.00)
#  - [Rule] 701.40g                        (sc: 0.56)
#  - [Rule] 406.3a                         (sc: 0.56)
#  - [Rule] 712.13                         (sc: 0.55)
#  - [Rule] 701.40f                        (sc: 0.55)
#  - [Rule] 712.16                         (sc: 0.54)
#  - [Rule] 701.27d                        (sc: 0.54)
#  - [Rule] 712.13a                        (sc: 0.54)
#  - [Rule] 712.10                         (sc: 0.53)
# ============================================================
#
# [LOG] Search Query: If [[Brawn]] is in my graveyard and I control only a [[Snow-Covered Forest]], will my creatures still have Trample?
# [LOG] Target Cards Identified: ['Snow-Covered Forest', 'Brawn']
#    >>> Found Card: Snow-Covered Forest
#    >>> Found Card: Brawn
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Snow-Covered Forest            (sc: 2.00)
#  - [Card] Brawn                          (sc: 2.00)
#  - [Rule] 702.19a                        (sc: 0.56)
#  - [Rule] 702.19                         (sc: 0.55)
#  - [Rule] Trample Over Planeswalkers     (sc: 0.54)
#  - [Rule] Trample                        (sc: 0.53)
#  - [Rule] 702.19b                        (sc: 0.53)
#  - [Rule] 702.14d                        (sc: 0.52)
#  - [Rule] 702.19c                        (sc: 0.52)
#  - [Rule] 702.19d                        (sc: 0.51)
# ============================================================
#
# [LOG] Search Query: If I have a [[Cecil, Dark Knight]] transformed into [[Cecil, Redeemed Paladin]], can I play a second [[Cecil, Dark Knight]] or will the legend rule make me sacrifice one?
# [LOG] Target Cards Identified: ['Cecil, Dark Knight', 'Cecil, Redeemed Paladin']
# [LOG] No exact cards found. Running semantic search.
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Cecil, Dark Knight // Cecil, Redeemed Paladin (sc: 0.73)
#  - [Rule] 712.9                          (sc: 0.56)
#  - [Card] Sengir, the Dark Baron         (sc: 0.54)
#  - [Card] Cavalier of Night              (sc: 0.54)
#  - [Card] Loyal Cathar // Unhallowed Cathar (sc: 0.53)
#  - [Card] Okiba Reckoner Raid // Nezumi Road Captain (sc: 0.53)
#  - [Rule] 616.1d                         (sc: 0.49)
#  - [Rule] 712.18                         (sc: 0.49)
#  - [Rule] 712.20                         (sc: 0.49)
#  - [Rule] 712.13a                        (sc: 0.49)
#  - [Rule] 616.1f                         (sc: 0.49)
#  - [Rule] 704.5j                         (sc: 0.49)
#  - [Rule] 704.5x                         (sc: 0.49)
# ============================================================
#
# [LOG] Search Query: I cast a [[Clown Car]], while I control [[Omarthis, Ghostfire Initiate]]. Will [[Omarthis]] get a counter for each counter [[Clown Car]] gets or just one?
# [LOG] Target Cards Identified: ['Omarthis, Ghostfire Initiate', 'Omarthis', 'Clown Car']
#    >>> Found Card: Omarthis, Ghostfire Initiate
#    >>> Found Card: Clown Car
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Omarthis, Ghostfire Initiate   (sc: 2.00)
#  - [Card] Clown Car                      (sc: 2.00)
#  - [Rule] 701.10e                        (sc: 0.43)
#  - [Rule] 122.8                          (sc: 0.42)
#  - [Rule] 606.5                          (sc: 0.42)
#  - [Rule] 122.6a                         (sc: 0.42)
#  - [Rule] 720.2c                         (sc: 0.42)
#  - [Rule] 201.2b                         (sc: 0.42)
#  - [Rule] 707.10e                        (sc: 0.42)
#  - [Rule] 706.8                          (sc: 0.41)
# ============================================================
#
# [LOG] Search Query: If my opponent has a [[Platinum Emperion]] out and I attack with [[Etali, Primal Sickness]] and they didn't block, would they still get the poison counters even though their life total can't change?
# [LOG] Target Cards Identified: ['Etali, Primal Sickness', 'Platinum Emperion']
#    >>> Found Card: Platinum Emperion
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Platinum Emperion              (sc: 2.00)
#  - [Rule] 904.13c                        (sc: 0.58)
#  - [Rule] 702.90b                        (sc: 0.57)
#  - [Rule] 810.10c                        (sc: 0.55)
#  - [Rule] 810.10b                        (sc: 0.54)
#  - [Rule] 810.10                         (sc: 0.54)
#  - [Rule] 104.3d                         (sc: 0.54)
#  - [Rule] 810.10a                        (sc: 0.54)
#  - [Rule] 810.10d                        (sc: 0.54)
# ============================================================
#
# [LOG] Search Query: If I have a [[Tajuru Blightblade]] and cast [[Blizzard Brawl]] targetting it and a 5/5 creature, does [[Blightblade]] kill that creature?
# [LOG] Target Cards Identified: ['Blightblade', 'Tajuru Blightblade', 'Blizzard Brawl']
#    >>> Found Card: Tajuru Blightblade
#    >>> Found Card: Blizzard Brawl
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Tajuru Blightblade             (sc: 2.00)
#  - [Card] Blizzard Brawl                 (sc: 2.00)
#  - [Rule] 120.5                          (sc: 0.47)
#  - [Rule] 506.4c                         (sc: 0.46)
#  - [Rule] 702.2b                         (sc: 0.46)
#  - [Rule] 508.4a                         (sc: 0.45)
#  - [Rule] 510.4                          (sc: 0.45)
#  - [Rule] 702.4b                         (sc: 0.45)
#  - [Rule] 702.7b                         (sc: 0.45)
#  - [Rule] 510.1c                         (sc: 0.45)
# ============================================================
#
# [LOG] Search Query: If I have a [[Phyrexian Obliterator]] and cast [[Blizzard Brawl]] targetting it and a 5/5 creature, does my opponent have to sacrifice 5 permanents?
# [LOG] Target Cards Identified: ['Blizzard Brawl', 'Phyrexian Obliterator']
#    >>> Found Card: Blizzard Brawl
#    >>> Found Card: Phyrexian Obliterator
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Blizzard Brawl                 (sc: 2.00)
#  - [Card] Phyrexian Obliterator          (sc: 2.00)
#  - [Rule] 614.12b                        (sc: 0.51)
#  - [Rule] 702.48b                        (sc: 0.51)
#  - [Rule] 508.4a                         (sc: 0.49)
#  - [Rule] 701.21a                        (sc: 0.49)
#  - [Rule] 120.5                          (sc: 0.48)
#  - [Rule] 702.119c                       (sc: 0.48)
#  - [Rule] 506.4c                         (sc: 0.48)
#  - [Rule] 608.3a                         (sc: 0.48)
# ============================================================
#
# [LOG] Search Query: I control [[Ghostly Prison]] and activate [[Nahiri, the Unforgiving]] +1 ability. Does this force my opponent to pay 2 mana to attack me?
# [LOG] Target Cards Identified: ['Ghostly Prison', 'Nahiri, the Unforgiving']
#    >>> Found Card: Ghostly Prison
#    >>> Found Card: Nahiri, the Unforgiving
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Ghostly Prison                 (sc: 2.00)
#  - [Card] Nahiri, the Unforgiving        (sc: 2.00)
#  - [Rule] 118.12                         (sc: 0.52)
#  - [Rule] 508.1h                         (sc: 0.52)
#  - [Rule] 509.1d                         (sc: 0.51)
#  - [Rule] 700.14                         (sc: 0.48)
#  - [Rule] 118.3c                         (sc: 0.48)
#  - [Rule] 509.1e                         (sc: 0.47)
#  - [Rule] 601.2h                         (sc: 0.47)
#  - [Rule] 702.51b                        (sc: 0.47)
# ============================================================
#
# [LOG] Search Query: If [[Blightbeetle]] blocks a green creature with trample is the excess damage still applied to the defending player?
# [LOG] Target Cards Identified: ['Blightbeetle']
#    >>> Found Card: Blightbeetle
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Blightbeetle                   (sc: 2.00)
#  - [Rule] 702.19b                        (sc: 0.63)
#  - [Rule] 702.19d                        (sc: 0.62)
#  - [Rule] 702.19e                        (sc: 0.60)
#  - [Rule] 510.1c                         (sc: 0.59)
#  - [Rule] 702.19f                        (sc: 0.56)
#  - [Rule] 510.1b                         (sc: 0.55)
#  - [Rule] 120.4a                         (sc: 0.55)
#  - [Rule] 702.19c                        (sc: 0.54)
# ============================================================
#
# [LOG] Search Query: Do I need to have [[The Omenkeel]] in play to play the lands exiled with it?
# [LOG] Target Cards Identified: ['The Omenkeel']
# [LOG] No exact cards found. Running semantic search.
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Omen Machine                   (sc: 0.59)
#  - [Card] Cosima, God of the Voyage // The Omenkeel (sc: 0.59)
#  - [Card] Valakut Exploration            (sc: 0.54)
#  - [Card] Omenpath Journey               (sc: 0.54)
#  - [Card] Release to the Wind            (sc: 0.53)
#  - [Rule] 406.5                          (sc: 0.53)
#  - [Rule] 406.3                          (sc: 0.52)
#  - [Rule] 607.2a                         (sc: 0.51)
#  - [Rule] 406.4                          (sc: 0.50)
#  - [Rule] 406.3a                         (sc: 0.49)
#  - [Rule] 400.7k                         (sc: 0.49)
#  - [Rule] 701.13                         (sc: 0.48)
#  - [Rule] 607.2b                         (sc: 0.48)
# ============================================================
#
# [LOG] Search Query: Can I play [[Consign to Memory]] to avoid paying the Ward 4 cost of [[Kappa Cannoneer]] and kill it with [[Dismember]]?
# [LOG] Target Cards Identified: ['Kappa Cannoneer', 'Dismember', 'Consign to Memory']
#    >>> Found Card: Kappa Cannoneer
#    >>> Found Card: Dismember
#    >>> Found Card: Consign to Memory
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Kappa Cannoneer                (sc: 2.00)
#  - [Card] Dismember                      (sc: 2.00)
#  - [Card] Consign to Memory              (sc: 2.00)
#  - [Rule] 702.51b                        (sc: 0.45)
#  - [Rule] 702.187c                       (sc: 0.44)
#  - [Rule] 702.139d                       (sc: 0.44)
#  - [Rule] 701.50a                        (sc: 0.43)
#  - [Rule] 118.12                         (sc: 0.43)
#  - [Rule] 702.168b                       (sc: 0.42)
#  - [Rule] 702.187b                       (sc: 0.42)
#  - [Rule] 614.12b                        (sc: 0.42)
# ============================================================
#
# [LOG] Search Query: If I control an [[Encroaching Mycosynth]], does [[Karn, the Great Creator]] -2 ability allow me to get any card from my sideboard/outside the game?
# [LOG] Target Cards Identified: ['Encroaching Mycosynth', 'Karn, the Great Creator']
#    >>> Found Card: Encroaching Mycosynth
#    >>> Found Card: Karn, the Great Creator
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Encroaching Mycosynth          (sc: 2.00)
#  - [Card] Karn, the Great Creator        (sc: 2.00)
#  - [Rule] 702.139d                       (sc: 0.57)
#  - [Rule] 712.13a                        (sc: 0.54)
#  - [Rule] 701.23j                        (sc: 0.51)
#  - [Rule] 601.3e                         (sc: 0.51)
#  - [Rule] 108.3b                         (sc: 0.51)
#  - [Rule] 903.11                         (sc: 0.51)
#  - [Rule] 903.3a                         (sc: 0.50)
#  - [Rule] 801.11                         (sc: 0.50)
# ============================================================
#
# [LOG] Search Query: If I target my [[Walking Ballista]] with [[Heliod, Sun-Crowned]] ability, does [[Ballista]] go infinite?
# [LOG] Target Cards Identified: ['Ballista', 'Heliod, Sun-Crowned', 'Walking Ballista']
#    >>> Found Card: Heliod, Sun-Crowned
#    >>> Found Card: Walking Ballista
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Heliod, Sun-Crowned            (sc: 2.00)
#  - [Card] Walking Ballista               (sc: 2.00)
#  - [Rule] 115.9a                         (sc: 0.41)
#  - [Rule] 115.7e                         (sc: 0.41)
#  - [Rule] 801.13a                        (sc: 0.41)
#  - [Rule] 115.9c                         (sc: 0.41)
#  - [Rule] 115.2                          (sc: 0.40)
#  - [Rule] 702.96b                        (sc: 0.40)
#  - [Rule] 115.4                          (sc: 0.40)
#  - [Rule] 601.2c                         (sc: 0.40)
# ============================================================
#
# [LOG] Search Query: If I cast [[Sculpting Steel]] as a copy of [[Cityscape Leveler]], do I get the 'When you cast this spell' trigger?
# [LOG] Target Cards Identified: ['Cityscape Leveler', 'Sculpting Steel']
#    >>> Found Card: Cityscape Leveler
#    >>> Found Card: Sculpting Steel
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Cityscape Leveler              (sc: 2.00)
#  - [Card] Sculpting Steel                (sc: 2.00)
#  - [Rule] 707.12                         (sc: 0.50)
#  - [Rule] 112.1b                         (sc: 0.48)
#  - [Rule] 400.7g                         (sc: 0.47)
#  - [Rule] 707.10                         (sc: 0.47)
#  - [Rule] 609.4a                         (sc: 0.47)
#  - [Rule] 400.7h                         (sc: 0.46)
#  - [Rule] 707.9g                         (sc: 0.46)
#  - [Rule] 707.10e                        (sc: 0.46)
# ============================================================
#
# [LOG] Search Query: I have a [[Vodalian Hexcatcher]] in play and multiple other merfolk creatures, and my opponent plays a noncreature spell. Can I sacrifice a merfolk then if my opponent decides to pay 1, sacrifice another one, and so on?
# [LOG] Target Cards Identified: ['Vodalian Hexcatcher']
#    >>> Found Card: Vodalian Hexcatcher
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Vodalian Hexcatcher            (sc: 2.00)
#  - [Rule] 702.119c                       (sc: 0.52)
#  - [Rule] 702.48b                        (sc: 0.51)
#  - [Rule] 118.12                         (sc: 0.50)
#  - [Rule] 702.180b                       (sc: 0.50)
#  - [Rule] 118.10                         (sc: 0.49)
#  - [Rule] 608.2d                         (sc: 0.48)
#  - [Rule] 118.13b                        (sc: 0.47)
#  - [Rule] 116.2e                         (sc: 0.47)
# ============================================================
#
# [LOG] Search Query: I control four copies of [[Hare Apparent]] and cast [[Ghostway]]. When they all return to the battlefield simultaneously, how many tokens do I create? Does each Hare see the other three?
# [LOG] Target Cards Identified: ['Hare Apparent', 'Ghostway']
#    >>> Found Card: Hare Apparent
#    >>> Found Card: Ghostway
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Hare Apparent                  (sc: 2.00)
#  - [Card] Ghostway                       (sc: 2.00)
#  - [Rule] 707.10e                        (sc: 0.49)
#  - [Rule] 616.1g                         (sc: 0.46)
#  - [Rule] 702.38b                        (sc: 0.45)
#  - [Rule] 707.10g                        (sc: 0.45)
#  - [Rule] 702.116b                       (sc: 0.45)
#  - [Rule] 701.12b                        (sc: 0.45)
#  - [Rule] 707.8a                         (sc: 0.45)
#  - [Rule] 707.3                          (sc: 0.45)
# ============================================================
#
# [LOG] Search Query: I am casting an opponent's card exiled with [[Gonti, Lord of Luxury]]. In response, he plays [[Aven Interrupter]] targeting that spell. Does the card go to my exile or the owner's exile, and who gets to cast it later?
# [LOG] Target Cards Identified: ['Aven Interrupter', 'Gonti, Lord of Luxury']
#    >>> Found Card: Aven Interrupter
#    >>> Found Card: Gonti, Lord of Luxury
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Aven Interrupter               (sc: 2.00)
#  - [Card] Gonti, Lord of Luxury          (sc: 2.00)
#  - [Rule] 715.3d                         (sc: 0.58)
#  - [Rule] 400.7k                         (sc: 0.53)
#  - [Rule] 712.21b                        (sc: 0.52)
#  - [Rule] 712.21c                        (sc: 0.52)
#  - [Rule] 702.35c                        (sc: 0.52)
#  - [Rule] 406.4                          (sc: 0.52)
#  - [Rule] 406.3a                         (sc: 0.52)
#  - [Rule] 406.3                          (sc: 0.52)
# ============================================================
#
# [LOG] Search Query: I control [[Nomads en-Kor]] and [[Needletooth Raptor]], and my opponent casts a spell that deals 2 damage to all creatures. If I activate [[Nomads en-Kor]] twice to redirect the damage it would take to the [[Needletooth Raptor]], will its Enrage ability trigger one, two, or three times?
# ...
# ============================================================
#
# [LOG] Search Query: If I create a token copy of a card with Mana Value (CMC) 5, what is the Mana Value of the token?
# [LOG] No exact cards found. Running semantic search.
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Smother                        (sc: 0.62)
#  - [Rule] 202.3c                         (sc: 0.57)
#  - [Card] Eliminate                      (sc: 0.55)
#  - [Rule] 202.3b                         (sc: 0.54)
#  - [Card] The Mana Rig                   (sc: 0.54)
#  - [Card] Mana Cylix                     (sc: 0.53)
#  - [Rule] 712.8g                         (sc: 0.53)
#  - [Rule] 202.3f                         (sc: 0.52)
#  - [Card] Relm's Sketching               (sc: 0.52)
#  - [Rule] 202.3                          (sc: 0.51)
#  - [Rule] Converted Mana Cost (Obsolete) (sc: 0.51)
#  - [Rule] Mana Value                     (sc: 0.49)
#  - [Rule] 202.3a                         (sc: 0.49)
# ============================================================
#
# [LOG] Search Query: Can I activate a Planeswalker ability during my opponent's turn?
# [LOG] No exact cards found. Running semantic search.
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Rule] 306.1                          (sc: 0.60)
#  - [Rule] 901.9c                         (sc: 0.59)
#  - [Rule] 901.8                          (sc: 0.57)
#  - [Rule] 901.11                         (sc: 0.57)
#  - [Card] Disallow                       (sc: 0.56)
#  - [Card] Cut Short                      (sc: 0.56)
#  - [Rule] 312.7                          (sc: 0.55)
#  - [Card] Planeswalker's Mischief        (sc: 0.55)
#  - [Card] Planar Disruption              (sc: 0.54)
#  - [Rule] 901.11a                        (sc: 0.54)
#  - [Card] The Chain Veil                 (sc: 0.54)
#  - [Rule] 701.31c                        (sc: 0.54)
#  - [Rule] 117.1b                         (sc: 0.54)
# ============================================================
#
# [LOG] Search Query: If I have a 1/1 creature with both Deathtouch and First Strike, and it blocks a 10/10 creature without abilities, does my creature die?
# [LOG] No exact cards found. Running semantic search.
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Rule] 704.5h                         (sc: 0.62)
#  - [Rule] 702.2b                         (sc: 0.62)
#  - [Card] Mirror Shield                  (sc: 0.61)
#  - [Card] Fight to the Death             (sc: 0.59)
#  - [Rule] 702.2c                         (sc: 0.58)
#  - [Rule] 702.2a                         (sc: 0.58)
#  - [Rule] 702.2d                         (sc: 0.57)
#  - [Rule] 510.4                          (sc: 0.57)
#  - [Card] Touch of Moonglove             (sc: 0.57)
#  - [Card] Master of Cruelties            (sc: 0.57)
#  - [Rule] 702.7b                         (sc: 0.57)
#  - [Rule] 702.4b                         (sc: 0.57)
#  - [Card] Undercity Uprising             (sc: 0.56)
# ============================================================
#
# [LOG] Search Query: I control [[Doubling Season]] and [[Parallel Lives]]. If I activate [[Luminarch Ascension]] to create a single 4/4 Angel token, how many Angels do I actually get?
# [LOG] Target Cards Identified: ['Luminarch Ascension', 'Doubling Season', 'Parallel Lives']
#    >>> Found Card: Luminarch Ascension
#    >>> Found Card: Doubling Season
#    >>> Found Card: Parallel Lives
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Luminarch Ascension            (sc: 2.00)
#  - [Card] Doubling Season                (sc: 2.00)
#  - [Card] Parallel Lives                 (sc: 2.00)
#  - [Rule] 616.1g                         (sc: 0.54)
#  - [Rule] 702.15e                        (sc: 0.48)
#  - [Rule] 201.2b                         (sc: 0.46)
#  - [Rule] 712.13a                        (sc: 0.45)
#  - [Rule] 701.63a                        (sc: 0.45)
#  - [Rule] 810.9a                         (sc: 0.44)
#  - [Rule] 701.10b                        (sc: 0.44)
#  - [Rule] 712.9                          (sc: 0.44)
# ============================================================
#
# [LOG] Search Query: What is the difference between 'Graveyard' and 'Exile'?
# [LOG] No exact cards found. Running semantic search.
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Rule] Exile                          (sc: 0.53)
#  - [Rule] 406.1                          (sc: 0.48)
#  - [Rule] 701.13                         (sc: 0.48)
#  - [Card] Grave Exchange                 (sc: 0.47)
#  - [Rule] Graveyard                      (sc: 0.47)
#  - [Card] Graveyard Shovel               (sc: 0.47)
#  - [Rule] 406.8                          (sc: 0.46)
#  - [Rule] 406.2                          (sc: 0.46)
#  - [Card] Cemetery Gatekeeper            (sc: 0.46)
#  - [Card] Shallow Grave                  (sc: 0.46)
#  - [Card] Silent Gravestone              (sc: 0.44)
#  - [Rule] 404.2                          (sc: 0.43)
#  - [Rule] 701.13a                        (sc: 0.43)
# ============================================================
#
# [LOG] Search Query: If I cast an Adventure creature spell (like [[Bonecrusher Giant]]), does it go to the graveyard after it resolves?
# [LOG] Target Cards Identified: ['Bonecrusher Giant']
# [LOG] No exact cards found. Running semantic search.
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Bonecrusher Giant // Stomp     (sc: 0.66)
#  - [Card] Realm-Cloaked Giant // Cast Off (sc: 0.61)
#  - [Card] Grabby Giant // That's Mine    (sc: 0.61)
#  - [Card] Giant Killer // Chop Down      (sc: 0.61)
#  - [Card] Altar of Bhaal // Bone Offering (sc: 0.60)
#  - [Rule] 715.3d                         (sc: 0.59)
#  - [Rule] 304.2                          (sc: 0.56)
#  - [Rule] 608.2n                         (sc: 0.55)
#  - [Rule] 307.2                          (sc: 0.54)
#  - [Rule] 302.2                          (sc: 0.52)
#  - [Rule] 608.3b                         (sc: 0.52)
#  - [Rule] 118.12                         (sc: 0.51)
#  - [Rule] 603.10a                        (sc: 0.51)
# ============================================================
#
# [LOG] Search Query: My opponent casts [[Deadly Dispute]]. Can I kill the creature they are sacrificing in response to make the spell fizzle?
# [LOG] Target Cards Identified: ['Deadly Dispute']
#    >>> Found Card: Deadly Dispute
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Deadly Dispute                 (sc: 2.00)
#  - [Rule] 701.12a                        (sc: 0.52)
#  - [Rule] 118.12                         (sc: 0.50)
#  - [Rule] 608.2d                         (sc: 0.50)
#  - [Rule] 702.48b                        (sc: 0.49)
#  - [Rule] 702.119c                       (sc: 0.48)
#  - [Rule] 603.12                         (sc: 0.47)
#  - [Rule] 601.3a                         (sc: 0.47)
#  - [Rule] 712.21c                        (sc: 0.46)
# ============================================================
#
# [LOG] Search Query: If I attack with a creature with Deathtouch and Trample and it gets blocked, how much damage do I need to assign to the blocker?
# [LOG] No exact cards found. Running semantic search.
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Rule] 702.19b                        (sc: 0.70)
#  - [Rule] 702.19d                        (sc: 0.64)
#  - [Rule] 510.1c                         (sc: 0.63)
#  - [Rule] 702.19e                        (sc: 0.61)
#  - [Rule] 510.1d                         (sc: 0.60)
#  - [Rule] 702.2c                         (sc: 0.59)
#  - [Card] Enlarge                        (sc: 0.59)
#  - [Rule] 510.1a                         (sc: 0.58)
#  - [Rule] 510.1                          (sc: 0.58)
#  - [Card] Ride Down                      (sc: 0.57)
#  - [Card] Mirror Shield                  (sc: 0.55)
#  - [Card] Deathcoil Wurm                 (sc: 0.54)
#  - [Card] Fight to the Death             (sc: 0.54)
# ============================================================
#
# [LOG] Search Query: Does [[Garruk's Harbinger]] (which has Hexproof from Black) survive a [[Damnation]]?
# [LOG] Target Cards Identified: ['Damnation', "Garruk's Harbinger"]
#    >>> Found Card: Damnation
#    >>> Found Card: Garruk's Harbinger
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Damnation                      (sc: 2.00)
#  - [Card] Garruk's Harbinger             (sc: 2.00)
#  - [Rule] 702.11e                        (sc: 0.49)
#  - [Rule] 702.11                         (sc: 0.48)
#  - [Rule] 702.11b                        (sc: 0.47)
#  - [Rule] 702.11c                        (sc: 0.45)
#  - [Rule] 702.11a                        (sc: 0.45)
#  - [Rule] 702.11d                        (sc: 0.43)
#  - [Rule] 120.5                          (sc: 0.42)
#  - [Rule] Hexproof                       (sc: 0.42)
# ============================================================
#
# [LOG] Search Query: If I cast [[Banishing Light]] and my opponent destroys it while its 'enters the battlefield' trigger is still on the stack, is the target exiled forever?
# [LOG] Target Cards Identified: ['Banishing Light']
#    >>> Found Card: Banishing Light
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Banishing Light                (sc: 2.00)
#  - [Rule] 603.7c                         (sc: 0.53)
#  - [Rule] 800.4d                         (sc: 0.52)
#  - [Rule] 715.3d                         (sc: 0.52)
#  - [Rule] 723.2b                         (sc: 0.51)
#  - [Rule] 723.1b                         (sc: 0.51)
#  - [Rule] 607.2q                         (sc: 0.51)
#  - [Rule] 120.5                          (sc: 0.51)
#  - [Rule] 712.21c                        (sc: 0.51)
# ============================================================
#
# [LOG] Search Query: Can I look at my sideboard during a game?
# [LOG] No exact cards found. Running semantic search.
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Rule] Sideboard                      (sc: 0.59)
#  - [Rule] 100.4                          (sc: 0.57)
#  - [Rule] 400.11a                        (sc: 0.57)
#  - [Rule] 100.4b                         (sc: 0.55)
#  - [Rule] 100.4a                         (sc: 0.54)
#  - [Rule] 103.2a                         (sc: 0.54)
#  - [Rule] 708.5                          (sc: 0.54)
#  - [Rule] 712.6                          (sc: 0.53)
#  - [Card] Wish                           (sc: 0.49)
#  - [Card] Boarded Window                 (sc: 0.47)
#  - [Card] Mastermind's Acquisition       (sc: 0.47)
#  - [Card] Keeper of the Lens             (sc: 0.47)
#  - [Card] Lens of Clarity                (sc: 0.46)
# ============================================================
#
# [LOG] Search Query: I am attacking with a Lifelink creature (without Trample). My opponent blocks it, then sacrifices his creature. Do I still gain life?
# [LOG] Target Cards Identified: ['Lifelink']
#    >>> Found Card: Lifelink
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Lifelink                       (sc: 2.00)
#  - [Rule] 702.15e                        (sc: 0.61)
#  - [Rule] 702.15b                        (sc: 0.59)
#  - [Rule] 120.3f                         (sc: 0.59)
#  - [Rule] 119.9                          (sc: 0.54)
#  - [Rule] 120.4d                         (sc: 0.54)
#  - [Rule] 702.15d                        (sc: 0.53)
#  - [Rule] 702.19b                        (sc: 0.53)
#  - [Rule] 701.12c                        (sc: 0.53)
# ============================================================
#
# [LOG] Search Query: I control [[Monastery Swiftspear]]. If I cast [[Shattering Spree]] and pay the Replicate cost twice, do I get 1 or 3 Prowess triggers?
# [LOG] Target Cards Identified: ['Shattering Spree', 'Monastery Swiftspear']
#    >>> Found Card: Shattering Spree
#    >>> Found Card: Monastery Swiftspear
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Shattering Spree               (sc: 2.00)
#  - [Card] Monastery Swiftspear           (sc: 2.00)
#  - [Rule] 702.108b                       (sc: 0.56)
#  - [Rule] 702.108a                       (sc: 0.56)
#  - [Rule] 603.12a                        (sc: 0.53)
#  - [Rule] Prowess                        (sc: 0.52)
#  - [Rule] 702.56b                        (sc: 0.51)
#  - [Rule] 702.56a                        (sc: 0.51)
#  - [Rule] Demonstrate                    (sc: 0.50)
#  - [Rule] 603.2d                         (sc: 0.49)
# ============================================================
#
# [LOG] Search Query: I have a [[Monastery Swiftspear]] and need one more Prowess trigger to win. Can I cast [[Spell Pierce]] even if there are no other spells on the stack, just to get the trigger?
# [LOG] Target Cards Identified: ['Spell Pierce', 'Monastery Swiftspear']
#    >>> Found Card: Spell Pierce
#    >>> Found Card: Monastery Swiftspear
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Spell Pierce                   (sc: 2.00)
#  - [Card] Monastery Swiftspear           (sc: 2.00)
#  - [Rule] 702.108a                       (sc: 0.58)
#  - [Rule] 117.2a                         (sc: 0.54)
#  - [Rule] Prowess                        (sc: 0.54)
#  - [Rule] 702.108b                       (sc: 0.53)
#  - [Rule] 807.5b                         (sc: 0.51)
#  - [Rule] 603.8                          (sc: 0.51)
#  - [Rule] 702.61b                        (sc: 0.50)
#  - [Rule] Respond                        (sc: 0.50)
# ============================================================
#
# [LOG] Search Query: If I attack with a creature with Trample and it becomes blocked, and I kill the blocker before the damage step, does the damage from my creature go through?
# [LOG] No exact cards found. Running semantic search.
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Rule] 702.19b                        (sc: 0.70)
#  - [Rule] 702.19d                        (sc: 0.69)
#  - [Rule] 702.19e                        (sc: 0.66)
#  - [Card] Ride Down                      (sc: 0.64)
#  - [Rule] 510.4                          (sc: 0.63)
#  - [Rule] 702.7b                         (sc: 0.63)
#  - [Rule] 702.4b                         (sc: 0.63)
#  - [Rule] 510.1c                         (sc: 0.62)
#  - [Rule] 702.19a                        (sc: 0.62)
#  - [Card] Enlarge                        (sc: 0.61)
#  - [Card] Barreling Attack               (sc: 0.60)
#  - [Card] Trap Runner                    (sc: 0.59)
#  - [Card] Crash Through                  (sc: 0.57)
# ============================================================
#
# [LOG] Search Query: If I crew a Vehicle to attack, at what specific moment does it stop being a creature?
# [LOG] No exact cards found. Running semantic search.
#
# ============================================================
# [LOG] RETRIEVAL CANDIDATES (After Filtering)
#  - [Card] Mobile Garrison                (sc: 0.64)
#  - [Card] Renegade Freighter             (sc: 0.64)
#  - [Card] Untethered Express             (sc: 0.63)
#  - [Card] Sleek Schooner                 (sc: 0.63)
#  - [Card] Bomat Bazaar Barge             (sc: 0.63)
#  - [Rule] 702.122d                       (sc: 0.62)
#  - [Rule] 702.122b                       (sc: 0.58)
#  - [Rule] 301.7b                         (sc: 0.57)
#  - [Rule] 508.1k                         (sc: 0.53)
#  - [Rule] 702.122a                       (sc: 0.53)
#  - [Rule] 301.7                          (sc: 0.53)
#  - [Rule] 702.122c                       (sc: 0.52)
#  - [Rule] Attacking Creature             (sc: 0.52)
# ============================================================

# %%
df_questions.head()
# Out:
#    id                                           question  \
# 0   1  I control [[Vizier of Remedies]] and [[Devoted...
# 1   2  I attack with [[Questing Beast]] and my oppone...
# 2   3  If my opponent casts [[Solitude]] on my [[Ketr...
# 3   4  I cast [[Dress Down]] and my opponent has a [[...
# 4   5  If I cast [[Merfolk Trickster]] on [[Dryad of ...
#
#                                      accepted_answer difficulty  \
# 0  Yes, you can. This works because the Vizier cr...       hard
# 1  Yes, with Questing Beast attacking, casting Fo...       hard
# 2  Yes, you will draw a card. Ketramose's ability...       hard
# 3  Yes, your non-basic lands will still be mounta...       hard
# 4  Yes, the lands remain Mountains. This happens ...       hard
#
#                                category  \
# 0    Costs, Mana & Casting Requirements
# 1             Combat & Damage Mechanics
# 2  Zones, Objects & State-Based Actions
# 3  Continuous Effects, Layers & Copying
# 4  Continuous Effects, Layers & Copying
#
#                                         model_answer
# 0  Ah, the pursuit of infinite mana—a most tantal...
# 1  Ah, the intricacies of combat and damage preve...
# 2  Ah, the intricacies of triggered abilities and...
# 3  Ah, the intricate dance of enchantments and cr...
# 4  Ah, a most intriguing inquiry regarding the in...

# %%
BASE_DIR = Path().resolve().parent
print(BASE_DIR)
json_path = BASE_DIR / "7-question_answer_set" / "curated_questions_owl.json"

with open(json_path, "r", encoding="utf-8") as f:
    data = json.load(f)



# 2. Crear el DataFrame de Preguntas
df_questions_v2 = pd.DataFrame(data)
# Out:
# /Users/leonardomichelramirez/code/PersonalProjects/DL-Mioti-Project

# %%
df_questions_v2.head()
# Out:
#    id                                           question  \
# 0   1  I control [[Vizier of Remedies]] and [[Devoted...
# 1   2  I activate [[Kiki-Jiki, Mirror Breaker]] targe...
# 2   3  If my opponent casts [[Solitude]] on my [[Ketr...
# 3   4  I cast [[Dress Down]] and my opponent has a [[...
# 4   5  If I cast [[Merfolk Trickster]] on [[Dryad of ...
#
#                                      accepted_answer difficulty  \
# 0  Yes, you can. This works because the Vizier cr...       hard
# 1  No, you do not create the token. This happens ...       hard
# 2  Yes, you will draw a card. Ketramose's ability...       hard
# 3  Yes, your non-basic lands will still be Mounta...       hard
# 4  Yes, the lands remain Mountains. This happens ...       hard
#
#                                category  \
# 0    Costs, Mana & Casting Requirements
# 1          The Stack, Timing & Priority
# 2  Zones, Objects & State-Based Actions
# 3  Continuous Effects, Layers & Copying
# 4  Continuous Effects, Layers & Copying
#
#                                           owl_answer
# 0  Read the text, boy! Read the text!\n\nYou have...
# 1  Hoo-hoo! Timing is everything, student! Listen...
# 2  Hoo-hoo! Timing is everything, student! Listen...
# 3  Squawk! A tangled web of layers. Let us untang...
# 4  Squawk! A tangled web of layers. Let us untang...

# %%
print(df_questions_v2.loc[2, 'owl_answer'])
# Out:
# Hoo-hoo! Timing is everything, student! Listen closely.
#
# When your opponent casts Solitude and exiles your Ketramose during your turn, we must consider the sequence of events and the abilities involved. Solitude's ability triggers upon entering the battlefield, allowing it to exile a target creature, in this case, Ketramose.
#
# **The Lecture**:
# 1. **Solitude's Trigger**: When Solitude enters the battlefield, its ability triggers, targeting Ketramose for exile. This ability resolves, and Ketramose is exiled.
# 2. **Ketramose's Trigger**: Ketramose has an ability that triggers whenever one or more cards are put into exile from graveyards and/or the battlefield during your turn. The key here is that Ketramose's ability looks at the event of cards being exiled, not the state of Ketramose itself.
# 3. **Last Known Information (LKI)**: Even though Ketramose is no longer on the battlefield when its ability would trigger, we use the Last Known Information rule to determine that it was indeed on the battlefield when the exile event occurred. Therefore, its ability can trigger and resolve.
#
# **The Ruling**: Yes, you draw a card and lose 1 life from Ketramose's ability when Solitude exiles it during your turn.
#
# **Sources**:
# - **Rule 603.2 (Triggered Abilities)**: Explains how triggered abilities function.
# - **Rule 400.7k (General)**: Discusses how effects can reference objects that have moved to a public zone.
# - **Rule 121.3 (Drawing a Card)**: Details the process of drawing cards.

# %% [markdown]
# ## Evaluating Responses 🧑🏻‍🏫

# %%
def get_eval_prompt_v3(question, ground_truth, model_answer):
    return f"""
    ROLE: 
    Lead MTG Judge Auditor. You are stone-cold, objective, and immune to sarcasm.
    
    IMPORTANT CONTEXT:
    The Bot is programmed to act like a "Grumpy Old Wizard". It uses flavor text, insults, and roleplay (e.g., "Read the text, boy!", "Hoo-hoo!"). 
    YOU MUST IGNORE THE ROLEPLAY. Do not let the flavor text affect your technical evaluation.

    DATA:
    - Question: {question}
    - Ground Truth: {ground_truth}
    - Bot's Answer: {model_answer}

    STRICT EVALUATION PROTOCOL:
    1. EXTRACT RULING: Go to "**The Ruling**:". If the ruling is there, the bot HAS answered and this is the final decision.
    2. COMPARE: Compare the statement found in "**The Ruling**" against the Ground Truth.
    3. CHECK CORE LOGIC: Does the bot's final decision (Yes/No/Can/Cannot) match the Ground Truth's decision?
    4. RULE VERIFICATION: If the bot cites a Rule Number (e.g., 704.5j), check if that rule is relevant to the topic.
    
    STRICT RULES:
    - The Bot is allowed to be verbose in sections before the ruling.
    - An answer is CORRECT if the final verdict in section "**The Rulling** matches the logic of the Ground Truth.
    - NEVER penalize for the bot's "arrogant" or "vague" persona if the technical MTG ruling is correct.
    - If the bot provides the correct rule number (e.g., 702.10 for Haste), it is a high-quality answer.

    OUTPUT FORMAT (JSON ONLY):
    {{
        "bot_verdict_detected": "The technical answer found in The Rulling",
        "score": (int 0-5),
        "verdict": "CORRECT" or "INCORRECT",
        "reasoning": "Focus ONLY on MTG rules. Explain why the ruling matches or differs from the ground truth."
    }}
    """

# %%
# funcción de evaluación
load_dotenv()
openai_api_key = os.getenv("OPENAI_API_KEY")

client = openai.OpenAI(api_key=openai_api_key)

def run_evaluation(df):
    results = []
    
    for idx, row in df.iterrows():
        print(f"Judging question {row['id']}...")
        
        prompt = get_eval_prompt_v3(row['question'], row['accepted_answer'], row['owl_answer'])
        
        try:
            response = client.chat.completions.create(
                model="gpt-4o",
                messages=[{"role": "system", "content": "You are a precise MTG Judge Evaluator."},
                          {"role": "user", "content": prompt}],
                response_format={ "type": "json_object" },
                temperature=0 # Queremos consistencia, no creatividad
            )
            
            evaluation = json.loads(response.choices[0].message.content)
            results.append(evaluation)
        except Exception as e:
            results.append({"score": 0, "verdict": "ERROR", "reasoning": str(e)})

    # Unimos los resultados al DataFrame original
    df_results = pd.concat([df, pd.DataFrame(results)], axis=1)
    return df_results

# %% [markdown]
# ## Building the Metrics 📈

# %%
# correr la evaluación en todo el dataset

df_eval = run_evaluation(df_questions_v2)
# Out:
# Judging question 1...
# Judging question 2...
# Judging question 3...
# Judging question 4...
# Judging question 5...
# Judging question 6...
# Judging question 7...
# Judging question 8...
# Judging question 9...
# Judging question 10...
# Judging question 11...
# Judging question 12...
# Judging question 13...
# Judging question 14...
# Judging question 15...
# Judging question 16...
# Judging question 17...
# Judging question 18...
# Judging question 19...
# Judging question 20...
# Judging question 21...
# Judging question 22...
# Judging question 23...
# Judging question 24...
# Judging question 25...
# Judging question 26...
# Judging question 27...
# Judging question 28...
# Judging question 29...
# Judging question 30...
# Judging question 31...
# Judging question 32...
# Judging question 33...
# Judging question 34...
# Judging question 35...
# Judging question 36...
# Judging question 37...
# Judging question 38...
# Judging question 39...
# Judging question 40...
# Judging question 41...
# Judging question 42...
# Judging question 43...
# Judging question 44...
# Judging question 45...
# Judging question 46...
# Judging question 47...
# Judging question 48...
# Judging question 49...
# Judging question 50...
# Judging question 51...
# Judging question 52...
# Judging question 53...
# Judging question 54...
# Judging question 55...
# Judging question 56...
# Judging question 57...
# Judging question 58...
# Judging question 59...
# Judging question 60...
# Judging question 61...
# Judging question 62...
# Judging question 63...
# Judging question 64...
# Judging question 65...
# Judging question 66...
# Judging question 67...
# Judging question 68...
# Judging question 69...
# Judging question 70...
# Judging question 71...
# Judging question 72...
# Judging question 73...
# Judging question 74...
# Judging question 75...
# Judging question 76...
# Judging question 77...
# Judging question 78...
# Judging question 79...
# Judging question 80...
# Judging question 81...
# Judging question 82...
# Judging question 83...
# Judging question 84...
# Judging question 85...
# Judging question 86...
# Judging question 87...
# Judging question 88...
# Judging question 89...
# Judging question 90...
# Judging question 91...
# Judging question 92...
# Judging question 93...
# Judging question 94...
# Judging question 95...
# Judging question 96...
# Judging question 97...
# Judging question 98...
# Judging question 99...
# Judging question 100...

# %%
df_eval.head()
# Out:
#    id                                           question  \
# 0   1  I control [[Vizier of Remedies]] and [[Devoted...
# 1   2  I activate [[Kiki-Jiki, Mirror Breaker]] targe...
# 2   3  If my opponent casts [[Solitude]] on my [[Ketr...
# 3   4  I cast [[Dress Down]] and my opponent has a [[...
# 4   5  If I cast [[Merfolk Trickster]] on [[Dryad of ...
#
#                                      accepted_answer difficulty  \
# 0  Yes, you can. This works because the Vizier cr...       hard
# 1  No, you do not create the token. This happens ...       hard
# 2  Yes, you will draw a card. Ketramose's ability...       hard
# 3  Yes, your non-basic lands will still be Mounta...       hard
# 4  Yes, the lands remain Mountains. This happens ...       hard
#
#                                category  \
# 0    Costs, Mana & Casting Requirements
# 1          The Stack, Timing & Priority
# 2  Zones, Objects & State-Based Actions
# 3  Continuous Effects, Layers & Copying
# 4  Continuous Effects, Layers & Copying
#
#                                           owl_answer  \
# 0  Read the text, boy! Read the text!\n\nYou have...
# 1  Hoo-hoo! Timing is everything, student! Listen...
# 2  Hoo-hoo! Timing is everything, student! Listen...
# 3  Squawk! A tangled web of layers. Let us untang...
# 4  Squawk! A tangled web of layers. Let us untang...
#
#                                 bot_verdict_detected  score  verdict  \
# 0         Yes, you can generate infinite Green mana.      5  CORRECT
# 1  You do not create a token. The ability is coun...      5  CORRECT
# 2  Yes, you draw a card and lose 1 life from Ketr...      5  CORRECT
# 3  Your nonbasic lands remain Mountains. The type...      5  CORRECT
# 4  Yes, your opponent's Valakut, the Molten Pinna...      5  CORRECT
#
#                                            reasoning
# 0  The bot's ruling matches the Ground Truth. Bot...
# 1  The bot's ruling matches the Ground Truth. Bot...
# 2  The bot's ruling matches the Ground Truth. Bot...
# 3  The bot's ruling correctly identifies that the...
# 4  The bot's ruling correctly identifies that the...

# %%
df_eval.to_csv("full_evaluation.csv", index=False)

# %% [markdown]
# ### Accuracy (Right Answers / Total Answers)

# %%
# accuracy general 
mask_correct = df_eval['verdict'] == 'CORRECT'
accuracy = len(df_eval[mask_correct]) / len(df_eval)

print(f"Accuracy over 100 questions: {accuracy*100:.2f}%")
# Out:
# Accuracy over 100 questions: 97.00%

# %%
## Accuracy por dificultad 

# filtro correctos
correct_eval = df_eval[mask_correct]

# conteo por dificultad (correctos)
correct_counts = correct_eval['difficulty'].value_counts().reset_index()
correct_counts.rename(columns={'count': 'count_correct'}, inplace=True)

# conteo por dificultad (total)
total_counts = df_eval['difficulty'].value_counts().reset_index()

accuracy_diff = total_counts.merge(correct_counts, on='difficulty', how='left')
accuracy_diff['accuracy'] = accuracy_diff['count_correct'] / accuracy_diff['count']

accuracy_diff
# Out:
#   difficulty  count  count_correct  accuracy
# 0       hard     50             47      0.94
# 1       easy     25             25      1.00
# 2     medium     25             25      1.00

# %%
categories = accuracy_diff['difficulty']

fig = make_subplots(
    rows=1,
    cols=2,
    specs=[[{'type': 'polar'}, {'type': 'polar'}]],
    subplot_titles=[
        "Accuracy (%) por Dificultad",
        "Preguntas Correctas por Dificultad"
    ]
)

# --- Radar 1: Accuracy en porcentaje ---
fig.add_trace(
    go.Scatterpolar(
        r=accuracy_diff['accuracy'] * 100,
        theta=categories,
        fill='toself',
        name='Accuracy (%)',
        line=dict(color='#636EFA'),
        marker=dict(size=8)
    ),
    row=1,
    col=1
)

# --- Radar 2: Conteo absoluto ---
fig.add_trace(
    go.Scatterpolar(
        r=accuracy_diff['count_correct'],
        theta=categories,
        fill='toself',
        name='Conteo',
        line=dict(color='#EF553B'),
        marker=dict(size=8)
    ),
    row=1,
    col=2
)

# --- Layout ---
fig.update_layout(
    showlegend=False,
    title="Model Performance vs Question Difficulty",
    polar=dict(
        radialaxis=dict(
            visible=True,
            range=[0, 100],
            ticksuffix="%"
        )
    ),
    polar2=dict(
        radialaxis=dict(
            visible=True,
            range=[0, max(accuracy_diff['count'])]
        )
    )
)

fig.show()

# %%
## Accuracy por categoría

# filtro correctos
correct_eval = df_eval[mask_correct]

# conteo por dificultad (correctos)
correct_counts = correct_eval['category'].value_counts().reset_index()
correct_counts.rename(columns={'count': 'count_correct'}, inplace=True)

# conteo por dificultad (total)
total_counts = df_eval['category'].value_counts().reset_index()

accuracy_cat = total_counts.merge(correct_counts, on='category', how='left')
accuracy_cat['count_correct'] = accuracy_cat['count_correct'].fillna(0)
accuracy_cat['count_correct'] = accuracy_cat['count_correct'].astype(int)

accuracy_cat['accuracy'] = accuracy_cat['count_correct'] / accuracy_cat['count']

accuracy_cat.sort_values(by='accuracy', ascending=False, inplace=True)

accuracy_cat
# Out:
#                                category  count  count_correct  accuracy
# 1             Combat & Damage Mechanics     24             24  1.000000
# 2          The Stack, Timing & Priority     22             22  1.000000
# 4  Continuous Effects, Layers & Copying     13             13  1.000000
# 3    Costs, Mana & Casting Requirements     15             14  0.933333
# 0  Zones, Objects & State-Based Actions     26             24  0.923077

# %%
categories = accuracy_cat['category']

fig = make_subplots(
    rows=1,
    cols=2,
    specs=[[{'type': 'polar'}, {'type': 'polar'}]],
    subplot_titles=[
        "Accuracy (%) por Categoría",
        "Preguntas Correctas por Categoría"
    ]
)

# --- Radar 1: Accuracy en porcentaje ---
fig.add_trace(
    go.Scatterpolar(
        r=accuracy_cat['accuracy'] * 100,
        theta=categories,
        fill='toself',
        name='Accuracy (%)',
        line=dict(color='#636EFA'),
        marker=dict(size=8)
    ),
    row=1,
    col=1
)

# --- Radar 2: Conteo absoluto ---
fig.add_trace(
    go.Scatterpolar(
        r=accuracy_cat['count_correct'],
        theta=categories,
        fill='toself',
        name='Conteo',
        line=dict(color='#EF553B'),
        marker=dict(size=8)
    ),
    row=1,
    col=2
)

# --- Layout ---
fig.update_layout(
    title = "Model Performance vs Question Category",
    showlegend=False,
    height=600,
    width=900,
    polar=dict(
        radialaxis=dict(
            visible=True,
            range=[0, 100],
            ticksuffix="%",
            
        ),
        angularaxis=dict(
            tickfont=dict(size=10)  
        )
    ),
    polar2=dict(
        radialaxis=dict(
            visible=True,
            range=[0, max(accuracy_cat['count'])]
        ),
        angularaxis=dict(
            tickfont=dict(size=10)  
        )
    )
)

fig.show()

# %%
## Accuracy por categoría dificil

# filtro correctos
mask = (df_eval['verdict'] == 'CORRECT') & (df_eval['difficulty'] == 'hard')
correct_eval_hard = df_eval[mask]

# conteo por dificultad (correctos)
correct_counts = correct_eval_hard['category'].value_counts().reset_index()
correct_counts.rename(columns={'count': 'count_correct'}, inplace=True)

# conteo por dificultad (total)
total_counts = df_eval[df_eval['difficulty'] == 'hard']['category'].value_counts().reset_index()

accuracy_cat_hard = total_counts.merge(correct_counts, on='category', how='left')
accuracy_cat_hard['count_correct'] = accuracy_cat_hard['count_correct'].fillna(0)
accuracy_cat_hard['count_correct'] = accuracy_cat_hard['count_correct'].astype(int)

accuracy_cat_hard['accuracy'] = accuracy_cat_hard['count_correct'] / accuracy_cat_hard['count']

accuracy_cat_hard.sort_values(by='accuracy', ascending=False, inplace=True)

accuracy_cat_hard
# Out:
#                                category  count  count_correct  accuracy
# 1          The Stack, Timing & Priority     12             12  1.000000
# 2  Continuous Effects, Layers & Copying     11             11  1.000000
# 4             Combat & Damage Mechanics      6              6  1.000000
# 0  Zones, Objects & State-Based Actions     15             13  0.866667
# 3    Costs, Mana & Casting Requirements      6              5  0.833333

# %%
categories = accuracy_cat_hard['category']

fig = make_subplots(
    rows=1,
    cols=2,
    specs=[[{'type': 'polar'}, {'type': 'polar'}]],
    subplot_titles=[
        "Accuracy (%) por Categoría",
        "Preguntas Correctas por Categoría"
    ]
)

# --- Radar 1: Accuracy en porcentaje ---
fig.add_trace(
    go.Scatterpolar(
        r=accuracy_cat_hard['accuracy'] * 100,
        theta=categories,
        fill='toself',
        name='Accuracy (%)',
        line=dict(color='#636EFA'),
        marker=dict(size=8)
    ),
    row=1,
    col=1
)

# --- Radar 2: Conteo absoluto ---
fig.add_trace(
    go.Scatterpolar(
        r=accuracy_cat_hard['count_correct'],
        theta=categories,
        fill='toself',
        name='Conteo',
        line=dict(color='#EF553B'),
        marker=dict(size=8)
    ),
    row=1,
    col=2
)

# --- Layout ---
fig.update_layout(
    title = "Model Performance vs Question Category (Hard)",
    showlegend=False,
    height=600,
    width=900,
    polar=dict(
        radialaxis=dict(
            visible=True,
            range=[0, 100],
            ticksuffix="%",
            
        ),
        angularaxis=dict(
            tickfont=dict(size=10)  
        )
    ),
    polar2=dict(
        radialaxis=dict(
            visible=True,
            range=[0, max(accuracy_cat_hard['count'])]
        ),
        angularaxis=dict(
            tickfont=dict(size=10)  
        )
    )
)

fig.show()

# %% [markdown]
# ### Mean Score

# %%
# mean score general
mean_score = df_eval['score'].mean()
print(f"Mean Score over 50 questions: {mean_score:.2f}")
# Out:
# Mean Score over 50 questions: 4.85

# %%
# mean scores por categoría
mean_scores_cat = df_eval.groupby('category').agg(
    mean_score = ('score', 'mean')
).reset_index()

mean_scores_cat.sort_values(by='mean_score', ascending=False, inplace=True)

# mean score por dificultad 
mean_scores_diff = df_eval.groupby('difficulty').agg(
    mean_score = ('score', 'mean')
).reset_index()

# %%
mean_scores_diff
# Out:
#   difficulty  mean_score
# 0       easy         5.0
# 1       hard         4.7
# 2     medium         5.0

# %%
mean_scores_cat
# Out:
#                                category  mean_score
# 0             Combat & Damage Mechanics    5.000000
# 1  Continuous Effects, Layers & Copying    5.000000
# 3          The Stack, Timing & Priority    5.000000
# 2    Costs, Mana & Casting Requirements    4.666667
# 4  Zones, Objects & State-Based Actions    4.615385

# %%
fig = make_subplots(
    rows=1,
    cols=2,
    subplot_titles=[
        "Mean Score por Dificultad",
        "Mean Score por Categoría"
    ]
)

fig.add_trace(
    go.Bar(
        x=mean_scores_diff['difficulty'],
        y=mean_scores_diff['mean_score'] ,
        name='Dificultad',
        marker_color='#636EFA'
    ),
    row=1,
    col=1
)

fig.add_trace(
    go.Bar(
        x=mean_scores_cat['category'],
        y=mean_scores_cat['mean_score'],
        name='Categorías',
        marker_color='#EF553B'
    ),
    row=1,
    col=2
)


fig.update_layout(
    title="Mean Scores",
    showlegend=False
)

fig.show()

# %% [markdown]
# ## Final Plots 🪄

# %%
accuracy_cat.sort_values(by='category', ascending=True, inplace=True)
accuracy_cat_hard.sort_values(by='category', ascending=True, inplace=True)

fig = make_subplots(
    rows=1,
    cols=2,
    specs=[[{'type': 'polar'}, {'type': 'polar'}]]
)


categories = accuracy_cat['category']

# --- Radar 1: Accuracy categoría ---
fig.add_trace(
    go.Scatterpolar(
        r=accuracy_cat['accuracy'] * 100,
        theta=categories,
        fill='toself',
        name='Accuracy (all questions)',
        line=dict(color='#636EFA'),
        marker=dict(size=8)
    ),
    row=1,
    col=1
)


categories_hard = accuracy_cat_hard['category']


# --- Radar 2: Accuracy preguntas dificiles ---
fig.add_trace(
    go.Scatterpolar(
        r=accuracy_cat_hard['accuracy'] * 100,
        theta=categories_hard,
        fill='toself',
        name='Accuracy (hard questions)',
        line=dict(color='#EF553B'),
        marker=dict(size=8)
    ),
    row=1,
    col=2
)

# --- Layout ---
fig.update_layout(
    showlegend=True,
    height=500,
    width=1200,
    title="Métrica Accuracy",
    polar=dict(
        radialaxis=dict(
            visible=True,
            range=[0, 100],
            ticksuffix="%"
        ),
        angularaxis=dict(
            tickfont=dict(size=8)
        )
    ),
    polar2=dict(
        radialaxis=dict(
            visible=True,
            range=[0, 100],
            ticksuffix="%"
        ),
         angularaxis=dict(
            tickfont=dict(size=8)
        )
    )
)

fig.show()

# %%
fig = make_subplots(
    rows=1,
    cols=2,
    specs=[[{'type': 'polar'}, {'type': 'bar'}]]
)
diff = accuracy_diff['difficulty']


# --- Radar 1: Accuracy en porcentaje ---
fig.add_trace(
    go.Scatterpolar(
        r=accuracy_diff['accuracy'] * 100,
        theta=diff,
        fill='toself',
        name='Accuracy',
        line=dict(color='#636EFA'),
        marker=dict(size=8)
    ),
    row=1,
    col=1
    
)

# --- Barra 1: Mean Score por Dificultad ---
fig.add_trace(
    go.Bar(
        x=mean_scores_diff['difficulty'],
        y=mean_scores_diff['mean_score'] ,
        name='Mean Score',
        marker_color='#EF553B'
    ),
    row=1,
    col=2
)



# --- Layout ---
fig.update_layout(
    title = "Métricas por Dificultad",
    showlegend=True,
    polar=dict(
        radialaxis=dict(
            visible=True,
            range=[0, 100],
            ticksuffix="%",
            
        ),
        angularaxis=dict(
            tickfont=dict(size=10)  
        )
    )
)

fig.show()
